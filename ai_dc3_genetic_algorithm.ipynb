# %% [markdown]
# # Genetic Algorithm
#
# - http://www.netlogoweb.org/launch#http://www.netlogoweb.org/assets/modelslib/Sample%20Models/Computer%20Science/Simple%20Genetic%20Algorithm.nlogo
# - http://www.netlogoweb.org/launch#http://www.netlogoweb.org/assets/modelslib/Sample%20Models/Biology/Evolution/Sunflower%20Biomorphs.nlogo

# %%
TARGET = 'Articifial Intelligence'

def compute_fitness(value: str, target: str):
    fitness = 0
    for val, tgt in zip(value, target):
        fitness += val == tgt # booleans in Python are just integers
    return fitness

compute_fitness('    cif hello world', TARGET)
# Out:
# 3

# %%
import random
import numpy as np

class Agent:
    def __init__(self, value: str) -> None:
        self.value = value

class Population:
    GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
                QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

    def __init__(self, n_pop: int, max_len: int) -> None:
        self.n_pop = n_pop
        self.max_len = max_len
        self.agents = []

    def populate(self):
        self.agents = [Agent(self.random_string()) for _ in range(self.n_pop)]

    def random_string(self):
        # sample from GENES pool and join genes together
        return ''.join(random.choice(self.GENES) for _ in range(self.max_len))
    
    def evaluate(self, target):
        # evaluate agents
        fitness_scores = [compute_fitness(a.value, target) for a in self.agents]
        # sort agents based on fitness score
        sorted_agents = sorted(zip(fitness_scores, self.agents), reverse=True, key=lambda x: x[0])
        # return sorted agent list and best agent 
        return [a for _, a in sorted_agents], sorted_agents[0]
    
    def cross_over(self, parents, mutation_rate=0.1):
        # define new generation
        new_population = Population(self.n_pop, self.max_len)

        for _ in range(new_population.n_pop):          
            # for n parents there are n-1 cutoffs  
            cutoffs = np.random.choice(self.max_len, len(parents)-1, replace=False).tolist()
            # to index, we need the begin and end indices (0 and max_len)
            cutoffs = sorted(list(set([0] + cutoffs + [self.max_len])))
            # take partitions from all parents and join the substrings
            value = ''.join([p.value[i:j] for i, j, p in zip(cutoffs, cutoffs[1:], parents)])

            # small random changes to not get stuck local optima
            if random.random() < mutation_rate:
                list_value = list(value)
                idx = random.randint(0, self.max_len-1)
                list_value[idx] = random.choice(self.GENES)
                value = ''.join(list_value)
            
            new_population.agents.append(Agent(value))
        
        return new_population

p = Population(10, 5)
p.populate()
[a.value for a in p.agents]
# Out:
# ['l8 s:',
#  ' ,7Zj',
#  'MM#Rz',
#  ' 9ZY ',
#  ']S"Wl',
#  '4N[$%',
#  '2UV I',
#  'I"h #',
#  'w )r@',
#  '$ b92']

# %%
num_parents = 2
mutation_rate = 0.05
population = Population(n_pop=200, max_len=len(TARGET))
population.populate()

for i in range(1000):
    sorted_agents, best_fitness = population.evaluate(TARGET)
    print(f'iter: {i}, best fitness: {best_fitness[0]}, value: "{sorted_agents[0].value}"')
    parents = sorted_agents[:num_parents]
    new_population = population.cross_over(parents, mutation_rate)
    population = new_population
    if sorted_agents[0].value == TARGET: break
# Out:
# iter: 0, best fitness: 2, value: "?IM6ZJ ICl  9$CB  lG]db"
# iter: 1, best fitness: 4, value: "?IM6ZJ ICl  e_bOY,#eAc "
# iter: 2, best fitness: 4, value: "?IM6ZJ ICl  e_bOY,#eAc "
# iter: 3, best fitness: 4, value: "?IM6ZJ ICl  e_bOY,#eAc "
# iter: 4, best fitness: 4, value: "?IM6ZJ ICl  e_bOY leAc "
# iter: 5, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 6, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 7, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 8, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 9, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 10, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 11, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 12, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 13, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 14, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 15, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 16, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 17, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 18, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 19, best fitness: 4, value: "?IM6ZJ ICl  e_bO  leAc "
# iter: 20, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 21, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 22, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 23, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 24, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 25, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 26, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 27, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 28, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 29, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 30, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 31, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 32, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 33, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 34, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 35, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 36, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 37, best fitness: 4, value: "?IM6ZJ 6Cl  e_bO  leAc "
# iter: 114, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 115, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 116, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 117, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 118, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 119, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 120, best fitness: 10, value: "?r-6Z(  al IqteO  geAc "
# iter: 121, best fitness: 11, value: "?r-6Z(f al IqteO  geAc "
# iter: 122, best fitness: 11, value: "?r-6Z(f al IqteO  geAc "
# iter: 123, best fitness: 11, value: "?r-6Z(f al IqteO  geAc "
# iter: 124, best fitness: 11, value: "?r-6Z(f al IqteO  geAc "
# iter: 125, best fitness: 11, value: "?r-6Z(f al IqteO  geAc "
# iter: 126, best fitness: 11, value: "?r-6Z(f al IqteO  geAc "
# iter: 127, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 128, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 129, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 130, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 131, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 132, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 133, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 134, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 135, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 136, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 137, best fitness: 12, value: "?r-6Z(f al IqteO  genc "
# iter: 138, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 139, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 140, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 141, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 142, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 143, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 144, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 145, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 146, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 147, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 148, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 149, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 150, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 151, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 152, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 153, best fitness: 13, value: "?r-6Z(f al Iqte0 igenc "
# iter: 154, best fitness: 13, value: "?r-6Z(f al Iqte0 igenc "
# iter: 155, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 156, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 157, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 158, best fitness: 13, value: "?r-6Z(f al IqteO igenc "
# iter: 159, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 160, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 161, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 162, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 163, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 164, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 165, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 166, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 167, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 168, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 169, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 170, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 171, best fitness: 14, value: "?r-6c(f al IqteO igenc "
# iter: 172, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 173, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 174, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 175, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 176, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 177, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 178, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 179, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 180, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 181, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 182, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 183, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 184, best fitness: 14, value: "Br-6c(f al IqteO igenc "
# iter: 185, best fitness: 14, value: "Br-6c(fEal IqteO igenc "
# iter: 186, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 187, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 188, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 189, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 190, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 191, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 192, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 193, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 194, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 195, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 196, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 197, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 198, best fitness: 15, value: "Br-ic(f al IqteO igenc "
# iter: 199, best fitness: 15, value: "Br-ic(f al IqteO igenc "
# iter: 200, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 201, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 202, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 203, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 204, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 205, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 206, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 207, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 208, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 209, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 210, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 211, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 212, best fitness: 15, value: "Br-ic(fEal IqteO igenc "
# iter: 213, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 214, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 215, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 216, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 217, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 218, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 219, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 220, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 221, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 222, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 223, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 224, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 225, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 226, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 227, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 228, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 229, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 230, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 231, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 232, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 233, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 234, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 235, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 236, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 237, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 238, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 239, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 240, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 241, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 242, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 243, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 244, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 245, best fitness: 15, value: "Br-ic(fEal Iqtez igenc "
# iter: 246, best fitness: 16, value: "Br-ic(fEal Intez igenc "
# iter: 247, best fitness: 16, value: "Br-ic(fEal Intez igenc "
# iter: 248, best fitness: 16, value: "Br-ic(fEal Intez igenc "
# iter: 249, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 250, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 251, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 252, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 253, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 254, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 255, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 256, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 257, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 258, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 259, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 260, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 261, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 262, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 263, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 264, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 265, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 266, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 267, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 268, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 269, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 270, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 271, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 272, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 273, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 274, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 275, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 276, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 277, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 278, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 279, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 280, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 281, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 282, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 283, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 284, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 285, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 286, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 287, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 288, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 289, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 290, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 291, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 292, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 293, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 294, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 295, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 296, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 297, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 298, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 299, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 300, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 301, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 302, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 303, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 304, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 305, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 306, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 307, best fitness: 17, value: "Br-ic(fEal Intez igence"
# iter: 308, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 309, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 310, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 311, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 312, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 313, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 314, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 315, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 316, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 317, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 318, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 319, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 320, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 321, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 322, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 323, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 324, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 325, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 326, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 327, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 328, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 329, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 330, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 331, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 332, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 333, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 334, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 335, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 336, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 337, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 338, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 339, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 340, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 341, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 342, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 343, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 344, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 345, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 346, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 347, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 348, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 349, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 350, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 351, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 352, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 353, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 354, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 355, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 356, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 357, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 358, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 359, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 360, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 361, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 362, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 363, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 364, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 365, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 366, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 367, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 368, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 369, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 370, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 371, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 372, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 373, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 374, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 375, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 376, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 377, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 378, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 379, best fitness: 17, value: "Br-ic(fEal Intez
# igence"
# iter: 380, best fitness: 18, value: "Br-ic(fEal Intel
# igence"
# iter: 381, best fitness: 18, value: "Br-ic(fEal Intel
# igence"
# iter: 382, best fitness: 18, value: "Br-ic(fEal Intel
# igence"
# iter: 383, best fitness: 18, value: "Br-ic(fEal Intel
# igence"
# iter: 384, best fitness: 18, value: "Br-ic(fEal Intel
# igence"
# iter: 385, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 386, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 387, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 388, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 389, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 390, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 391, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 392, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 393, best fitness: 19, value: "Brtic(fEal Intel
# igence"
# iter: 394, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 395, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 396, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 397, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 398, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 399, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 400, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 401, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 402, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 403, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 404, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 405, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 406, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 407, best fitness: 19, value: "BrticefEal Intel
# igence"
# iter: 408, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 409, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 410, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 411, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 412, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 413, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 414, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 415, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 416, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 417, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 418, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 419, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 420, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 421, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 422, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 423, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 424, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 425, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 426, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 427, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 428, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 429, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 430, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 431, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 432, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 433, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 434, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 435, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 436, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 437, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 438, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 439, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 440, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 441, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 442, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 443, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 444, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 445, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 446, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 447, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 448, best fitness: 20, value: "BrticefEal Intelligence"
# iter: 449, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 450, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 451, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 452, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 453, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 454, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 455, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 456, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 457, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 458, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 459, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 460, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 461, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 462, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 463, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 464, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 465, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 466, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 467, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 468, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 469, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 470, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 471, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 472, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 473, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 474, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 475, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 476, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 477, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 478, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 479, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 480, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 481, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 482, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 483, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 484, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 485, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 486, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 487, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 488, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 489, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 490, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 491, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 492, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 493, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 494, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 495, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 496, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 497, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 498, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 499, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 500, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 501, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 502, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 503, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 504, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 505, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 506, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 507, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 508, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 509, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 510, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 511, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 512, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 513, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 514, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 515, best fitness: 20, value: "BrticefXal Intelligence"
# iter: 516, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 517, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 518, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 519, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 520, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 521, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 522, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 523, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 524, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 525, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 526, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 527, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 528, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 529, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 530, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 531, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 532, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 533, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 534, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 535, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 536, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 537, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 538, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 539, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 540, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 541, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 542, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 543, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 544, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 545, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 546, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 547, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 548, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 549, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 550, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 551, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 552, best fitness: 20, value: "BrticQfXal Intelligence"
# iter: 553, best fitness: 20, value: "BrticQfXal Intelligence"
# iter:
best fitness: 21, value: "!rticifXal Intelligence"
# iter: 771, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 772, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 773, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 774, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 775, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 776, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 777, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 778, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 779, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 780, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 781, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 782, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 783, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 784, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 785, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 786, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 787, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 788, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 789, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 790, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 791, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 792, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 793, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 794, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 795, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 796, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 797, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 798, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 799, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 800, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 801, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 802, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 803, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 804, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 805, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 806, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 807, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 808, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 809, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 810, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 811, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 812, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 813, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 814, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 815, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 816, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 817, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 818, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 819, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 820, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 821, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 822, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 823, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 824, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 825, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 826, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 827, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 828, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 829, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 830, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 831, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 832, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 833, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 834, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 835, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 836, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 837, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 838, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 839, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 840, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 841, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 842, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 843, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 844, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 845, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 846, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 847, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 848, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 849, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 850, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 851, best fitness: 21, value: "!rticifXal Intelligence"
# iter: 852, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 853, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 854, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 855, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 856, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 857, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 858, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 859, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 860, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 861, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 862, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 863, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 864, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 865, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 866, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 867, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 868, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 869, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 870, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 871, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 872, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 873, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 874, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 875, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 876, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 877, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 878, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 879, best fitness: 22, value: "ArticifXal Intelligence"
# iter: 880, best fitness: 23, value: "Articifial Intelligence"

# %% [markdown]
# ## Distribute numbers to match sum and product
#
# Given a sequence of numbers from $1$ up until $m$, divide this set of numbers in two groups $A$ and $B$, such that the sum of $A$ is as close as possible to a predefined target sum, and the product of $B$ is as close as possible to a predefined target product. This means that you can only use each number once in either $A$ or $B$.
#
# The numbers you are allowed to use are $1$ up until $10$. The target sum is $38$ and the target product is $210$. Write a Genetic Algorithm that provides a good solution to this problem. Try to play around with the population size, number of iterations, and the mutation rate.

# %%
import math

# %%
# Problem solution
sol = [1, 0, 0, 1, 0, 1, 0, 1, 1, 1]

sum(i+1 for i in range(len(sol)) if sol[i] == 1), math.prod(i+1 for i in range(len(sol)) if sol[i] == 0)

# %%
TARGET_SUM, TARGET_PROD = (38, 210)
N_NUMS = 10

# helper function to get the sum (A) and product (B)
def sum_product(solution):
    A = sum(i+1 for i in range(len(solution)) if solution[i] == 1)
    B = math.prod(i+1 for i in range(len(solution)) if solution[i] == 0)
    return A, B

# fitness function measures how wrong the sum and product are 
# with respect to the target sum and target product
def fitness(solution):
    A, B = sum_product(solution)
    error_A = abs(TARGET_SUM - A)/TARGET_SUM
    error_B = abs(TARGET_PROD - B)/TARGET_PROD
    return error_A + error_B

# %%
# initialisation happens by creating random permutations of (0/1) binary lists
def initialise_population(pop_size):
    population = []
    for _ in range(pop_size):
        population.append([random.randint(0, 1) for _ in range(N_NUMS)])
    return population

# evaluate entire population and return fitness scores
def evaluate(population):
    fitness_scores = [fitness(solution) for solution in population]
    return fitness_scores

# sort individuals and return two best members of the population
def parent_selection(population, fitness_scores):
    # pairwise coupling of two lists
    paired_population = zip(fitness_scores, population)
    # sort individuals based on fitness scores
    sorted_population = [value for fitness, value in sorted(paired_population, reverse=False)]
    return sorted_population[0], sorted_population[1]

# random cutoff point determines which parts of the binary representation
# of the parents are recombined to create children solutions
def single_point_crossover(p1, p2):
        
    # determine cutoff point
    cutoff = random.randint(0, N_NUMS-1)
    # recombine
    c1 = p1[:cutoff] + p2[cutoff:]
    c2 = p2[:cutoff] + p1[cutoff:]
    return c1, c2

# mutate an individual randomly by flipping a single bit 
def mutate(individual, mutation_rate=0.1):
    if random.random() < mutation_rate:    
        idx = random.randint(0, N_NUMS-1)
        individual[idx] = 1*(not individual[idx]) # multiply True/False by 1 to get 1/0 values
    
    return individual

# %%
# GA parameters
N_POP = 10
N_ITERS = 20
MUTATION_RATE = 0.05

# INITIALISE population with random candidate solutions
population = initialise_population(N_POP)

# EVALUATE each candidate
fitness_scores = evaluate(population)

for i in range(N_ITERS): # REPEAT UNTIL (TERMINATION CONDITION is satisfied)

    # SELECT parents
    p1, p2 = parent_selection(population, fitness_scores)

    best_sum, best_prod = sum_product(p1)
    print(i, p1, min(fitness_scores), (best_sum, best_prod))
    
    # RECOMBINE pairs of parents
    offspring = []
    for j in range(N_POP//2):
        c1, c2 = single_point_crossover(p1, p2)
        # MUTATE the resulting offspring
        offspring.append(mutate(c1, MUTATION_RATE))
        offspring.append(mutate(c2, MUTATION_RATE))

    # EVALUATE new candidates
    fitness_offspring = evaluate(offspring)

    # SELECT individuals for the next generation
    total_fitness = fitness_scores + fitness_offspring
    total_population = population + offspring
    total_paired = zip(total_fitness, total_population)
    
    total_sorted = sorted(total_paired, reverse=False)
    new_population = [value for _, value in total_sorted]
    new_fitness_scores = [fitness for fitness, _ in total_sorted]
    
    population = new_population[:N_POP]
    fitness_scores = new_fitness_scores[:N_POP]

    if fitness(p1) == 0: break
